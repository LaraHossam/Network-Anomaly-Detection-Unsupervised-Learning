# %% [markdown]
# # Network Anomaly Detection using Clustering

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics.pairwise import rbf_kernel
import random
random.seed(42)
import warnings
warnings.filterwarnings('ignore')
from sklearn.cluster import KMeans
import numpy as np
import math
from scipy.optimize import linear_sum_assignment
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.cluster import SpectralClustering
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 1. Importing Data and Understanding Format

# %%
from ipynb.fs.full.data_preprocessing import preprocess_data_10, preprocess_data, category_map
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [51], in <cell line: 1>()
# ----> 1 from ipynb.fs.full.data_preprocessing import preprocess_data_10, preprocess_data, category_map
#
# ImportError: cannot import name 'category_map' from 'ipynb.fs.full.data_preprocessing' (unknown location)

# %%
data_k_means, labels_kmeans = preprocess_data_10()
data_spectral, labels_spectral = preprocess_data()

# %%
# from collections import Counter, OrderedDict
# d = Counter(labels_spectral)
# OrderedDict(sorted(d.items()))

# %% [markdown]
# # 2.  Clustering Using K-Means and Normalized Cut (Your implementation)

# %% [markdown]
# ### K-Means algorithm

# %%
#It takes two attrs k number of centroids and the whole data set number of samples x features

def kMeans_implemented(k,data):
    centroids=[]
    num_points=data.shape[0]
    num_features=data.shape[1]
    
    #Appending random points to be our centroids according to the number of ks
    for i in range(k):
        centroids.append(data[random.randint(0, num_points)])
    clusters={}
    t=0
    while(True):
        labels=[]
        #Initialize empty clusters
        for i in range (k):
            clusters[i]=[]
            
        #Classify the points according to the closest centroid
        for i in range(num_points):
            distances=[]
            for j in range(k):
                distances.append(np.linalg.norm(data[i]-centroids[j]))
            clusters[distances.index(min(distances))].append(data[i])
            labels.append(distances.index(min(distances)))
        new_centroids=np.zeros((k,num_features))
        
        #Measuring the new centroids
        for i in range(k):
            new_centroids[i]=np.mean(clusters[i],axis=0)
        if(centroids==new_centroids).all():
            break
        else:
            centroids=new_centroids
    return labels

# %% [markdown]
# ### Spectral Clustering algorithm

# %%
from sklearn.cluster import KMeans
def spectral_clustering(A,k):
        
    #--------------computing the degree matrix-------------
    d = np.diag(np.sum(A, axis=1))

    #--------------------computing L-----------------------
    L = d-A

    #---------------------computing La---------------------
    #computing the inverse of the dgree matrix
    inv_degree = np.linalg.inv(d)
    La = np.dot(inv_degree, L)

    #---computing the eigenValues and eigenVectors of La---
    e_val, evec = np.linalg.eig(La)

    #----------sorting the eigenValues ascending----------- 
    idx = np.argsort(eval)
    e_val = e_val[idx]

    #---sorting the eigenVectors according to their corresponding eigenValues---
    evec = evec[:, idx]

    #--slicing the eigenVectors to the desired number of clusters--
    evec_new = evec[:, :k]

    #-------------normalizing the eigenVectors--------------
    system = evec.real / np.sqrt(np.linalg.norm(evec.real))

    kmeans = KMeans(n_clusters=k)
    system_labels = kmeans.fit_predict(system)


    return system, system_labels

# %% [markdown]
# ## GMM algorithm

# %%
from sklearn.mixture import GaussianMixture

# Create a Gaussian Mixture Model with 23 components
gmm = GaussianMixture(n_components=23)

# Fit the model to the data
gmm.fit(X_train)

# Predict the cluster labels for the data
labels = gmm.predict(X_train)

# %%
mapping, labels = map_and_change(y_train,labels)

# %% [markdown]
# # Testing

# %% [markdown]
# ## K-Means Testing

# %%
labels1 = kMeans_implemented(7,np.array(data_k_means))
labels2 = kMeans_implemented(15,np.array(data_k_means))
labels3 = kMeans_implemented(23,np.array(data_k_means))
labels4 = kMeans_implemented(31,np.array(data_k_means))
labels5 = kMeans_implemented(45,np.array(data_k_means))

# %%
#labels = kMeans_implemented(7,np.array(data_k_means))
contingency_matrix = get_contingency(7,labels1,np.array(labels_kmeans))
evaluation(np.array(data_k_means),contingency_matrix)
# Out:
# ---------Conditional Entropy--------------------
# Conditional Entropy: 0.3560348999697181
# ----------------Purity---------------------------
# Purity: 0.9272320140672868
# --------------F-measure---------------------------
# F: 0.37852397344067573
# --------------Max matching------------------------
# Max Matching: 0.5359237838803181

# %%
#labels = kMeans_implemented(15,np.array(data_k_means))
contingency_matrix = get_contingency(15,labels2,np.array(labels_kmeans))
evaluation(np.array(data_k_means),contingency_matrix)
# Out:
# ---------Conditional Entropy--------------------
# Conditional Entropy: 0.18373219846534355
# ----------------Purity---------------------------
# Purity: 0.9736444438338849
# --------------F-measure---------------------------
# F: 0.41680386111088813
# --------------Max matching------------------------
# Max Matching: 0.42480733037517343

# %%
#labels = kMeans_implemented(23,np.array(data_k_means))
contingency_matrix = get_contingency(23,labels3,np.array(labels_kmeans))
evaluation(data_k_means,contingency_matrix)
# Out:
# ---------Confusion Matrix----------------------
# Rand Index: 0.6102798232289484
# Jaccard Index: 0.21108268697057267
# TP= 1105045771,TN= 5362436707.0,FN= 4097006802.0,FP= 33079625.0
# ---------Conditional Entropy--------------------
# Conditional Entropy: 0.15197479620500717
# ----------------Purity---------------------------
# Purity: 0.9755677056859864
# --------------F-measure---------------------------
# F: 0.2899171883013299
# --------------Max matching------------------------
# Max Matching: 0.33036830464467737

# %%
#labels = kMeans_implemented(31,np.array(data_k_means))
contingency_matrix = get_contingency(31,labels4,np.array(labels_kmeans))
evaluation(np.array(data_k_means),contingency_matrix)
# Out:
# ---------Conditional Entropy--------------------
# Conditional Entropy: 0.1373032330683246
# ----------------Purity---------------------------
# Purity: 0.9748739576607641
# --------------F-measure---------------------------
# F: 0.2474324622398687
# --------------Max matching------------------------
# Max Matching: 0.29583888560713256

# %%
#labels = kMeans_implemented(45,np.array(data_k_means))
contingency_matrix = get_contingency(45,labels5,np.array(labels_kmeans))
evaluation(np.array(data_k_means),contingency_matrix)
# Out:
# ---------Conditional Entropy--------------------
# Conditional Entropy: 0.14802197270368977
# ----------------Purity---------------------------
# Purity: 0.9694476117209071
# --------------F-measure---------------------------
# F: 0.16965070847395466
# --------------Max matching------------------------
# Max Matching: 0.21982882969516299

# %% [markdown]
# ## Spectral Clustering Testing

# %%
# Splitting data to use it in spectral clustering
X_train, X_test, y_train, y_test = train_test_split(data_spectral, labels_spectral, test_size=0.995, train_size=0.005,stratify=labels_spectral,random_state=42)

# %%
# from collections import Counter, OrderedDict
# d = Counter(y_train)
# OrderedDict(sorted(d.items()))

# %%
# from collections import Counter, OrderedDict
# d = Counter(y_test)
# OrderedDict(sorted(d.items()))

# %%
# Explore the classes in training dataset after splitting
for i in y_train.unique():
    print(category_map(i))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [26], in <cell line: 1>()
# ----> 1 category(1)
#
# File ~\Documents\Term8\Pattern\Assignment_2\Network-Anomaly-Detection-Unsupervised-Learning\data_preprocessing.ipynb:217, in category(x)
#       1 {
#       2  "cells": [
#       3   {
#       4    "cell_type": "markdown",
#       5    "id": "222311ee",
#       6    "metadata": {},
#       7    "source": [
#       8     "# 1. Download Dataset and Understand the Format"
#       9    ]
#      10   },
#      11   {
#      12    "cell_type": "code",
#      13    "execution_count": 1,
#      14    "id": "15e04c97",
#      15    "metadata": {},
#      16    "outputs": [],
#      17    "source": [
#      18     "import pandas as pd\n",
#      19     "import numpy as np\n",
#      20     "from sklearn.feature_extraction.text import CountVectorizer\n",
#      21     "from sklearn.preprocessing import StandardScaler\n",
#      22     "from sklearn.preprocessing import LabelEncoder"
#      23    ]
#      24   },
#      25   {
#      26    "cell_type": "code",
#      27    "execution_count": 2,
#      28    "id": "54602f9a",
#      29    "metadata": {},
#      30    "outputs": [],
#      31    "source": [
#      32     "features = [\"duration\",\"protocol_type\",\"service\",\"flag\",\"src_bytes\",\n",
#      33     "    \"dst_bytes\",\"land\",\"wrong_fragment\",\"urgent\",\"hot\",\"num_failed_logins\",\n",
#      34     "    \"logged_in\",\"num_compromised\",\"root_shell\",\"su_attempted\",\"num_root\",\n",
#      35     "    \"num_file_creations\",\"num_shells\",\"num_access_files\",\"num_outbound_cmds\",\n",
#      36     "    \"is_host_login\",\"is_guest_login\",\"count\",\"srv_count\",\"serror_rate\",\n",
#      37     "    \"srv_serror_rate\",\"rerror_rate\",\"srv_rerror_rate\",\"same_srv_rate\",\n",
#      38     "    \"diff_srv_rate\",\"srv_diff_host_rate\",\"dst_host_count\",\"dst_host_srv_count\",\n",
#      39     "    \"dst_host_same_srv_rate\",\"dst_host_diff_srv_rate\",\"dst_host_same_src_port_rate\",\n",
#      40     "    \"dst_host_srv_diff_host_rate\",\"dst_host_serror_rate\",\"dst_host_srv_serror_rate\",\n",
#      41     "    \"dst_host_rerror_rate\",\"dst_host_srv_rerror_rate\",\"label\"]"
#      42    ]
#      43   },
#      44   {
#      45    "cell_type": "code",
#      46    "execution_count": 3,
#      47    "id": "f9fd6c2b",
#      48    "metadata": {},
#      49    "outputs": [
#      50     {
#      51      "data": {
#      52       "text/html": [
#      53        "<div>\n",
#      54        "<style scoped>\n",
#      55        "    .dataframe tbody tr th:only-of-type {\n",
#      56        "        vertical-align: middle;\n",
#      57        "    }\n",
#      58        "\n",
#      59        "    .dataframe tbody tr th {\n",
#      60        "        vertical-align: top;\n",
#      61        "    }\n",
#      62        "\n",
#      63        "    .dataframe thead th {\n",
#      64        "        text-align: right;\n",
#      65        "    }\n",
#      66        "</style>\n",
#      67        "<table border=\"1\" class=\"dataframe\">\n",
#      68        "  <thead>\n",
#      69        "    <tr style=\"text-align: right;\">\n",
#      70        "      <th></th>\n",
#      71        "      <th>duration</th>\n",
#      72        "      <th>protocol_type</th>\n",
#      73        "      <th>service</th>\n",
#      74        "      <th>flag</th>\n",
#      75        "      <th>src_bytes</th>\n",
#      76        "      <th>dst_bytes</th>\n",
#      77        "      <th>land</th>\n",
#      78        "      <th>wrong_fragment</th>\n",
#      79        "      <th>urgent</th>\n",
#      80        "      <th>hot</th>\n",
#      81        "      <th>...</th>\n",
#      82        "      <th>dst_host_srv_count</th>\n",
#      83        "      <th>dst_host_same_srv_rate</th>\n",
#      84        "      <th>dst_host_diff_srv_rate</th>\n",
#      85        "      <th>dst_host_same_src_port_rate</th>\n",
#      86        "      <th>dst_host_srv_diff_host_rate</th>\n",
#      87        "      <th>dst_host_serror_rate</th>\n",
#      88        "      <th>dst_host_srv_serror_rate</th>\n",
#      89        "      <th>dst_host_rerror_rate</th>\n",
#      90        "      <th>dst_host_srv_rerror_rate</th>\n",
#      91        "      <th>label</th>\n",
#      92        "    </tr>\n",
#      93        "  </thead>\n",
#      94        "  <tbody>\n",
#      95        "    <tr>\n",
#      96        "      <th>0</th>\n",
#      97        "      <td>0</td>\n",
#      98        "      <td>tcp</td>\n",
#      99        "      <td>http</td>\n",
#     100        "      <td>SF</td>\n",
#     101        "      <td>181</td>\n",
#     102        "      <td>5450</td>\n",
#     103        "      <td>0</td>\n",
#     104        "      <td>0</td>\n",
#     105        "      <td>0</td>\n",
#     106        "      <td>0</td>\n",
#     107        "      <td>...</td>\n",
#     108        "      <td>9</td>\n",
#     109        "      <td>1.0</td>\n",
#     110        "      <td>0.0</td>\n",
#     111        "      <td>0.11</td>\n",
#     112        "      <td>0.0</td>\n",
#     113        "      <td>0.0</td>\n",
#     114        "      <td>0.0</td>\n",
#     115        "      <td>0.0</td>\n",
#     116        "      <td>0.0</td>\n",
#     117        "      <td>normal.</td>\n",
#     118        "    </tr>\n",
#     119        "    <tr>\n",
#     120        "      <th>1</th>\n",
#     121        "      <td>0</td>\n",
#     122        "      <td>tcp</td>\n",
#     123        "      <td>http</td>\n",
#     124        "      <td>SF</td>\n",
#     125        "      <td>239</td>\n",
#     126        "      <td>486</td>\n",
#     127        "      <td>0</td>\n",
#     128        "      <td>0</td>\n",
#     129        "      <td>0</td>\n",
#     130        "      <td>0</td>\n",
#     131        "      <td>...</td>\n",
#     132        "      <td>19</td>\n",
#     133        "      <td>1.0</td>\n",
#     134        "      <td>0.0</td>\n",
#     135        "      <td>0.05</td>\n",
#     136        "      <td>0.0</td>\n",
#     137        "      <td>0.0</td>\n",
#     138        "      <td>0.0</td>\n",
#     139        "      <td>0.0</td>\n",
#     140        "      <td>0.0</td>\n",
#     141        "      <td>normal.</td>\n",
#     142        "    </tr>\n",
#     143        "    <tr>\n",
#     144        "      <th>2</th>\n",
#     145        "      <td>0</td>\n",
#     146        "      <td>tcp</td>\n",
#     147        "      <td>http</td>\n",
#     148        "      <td>SF</td>\n",
#     149        "      <td>235</td>\n",
#     150        "      <td>1337</td>\n",
#     151        "      <td>0</td>\n",
#     152        "      <td>0</td>\n",
#     153        "      <td>0</td>\n",
#     154        "      <td>0</td>\n",
#     155        "      <td>...</td>\n",
#     156        "      <td>29</td>\n",
#     157        "      <td>1.0</td>\n",
#     158        "      <td>0.0</td>\n",
#     159        "      <td>0.03</td>\n",
#     160        "      <td>0.0</td>\n",
#     161        "      <td>0.0</td>\n",
#     162        "      <td>0.0</td>\n",
#     163        "      <td>0.0</td>\n",
#     164        "      <td>0.0</td>\n",
#     165        "      <td>normal.</td>\n",
#     166        "    </tr>\n",
#     167        "    <tr>\n",
#     168        "      <th>3</th>\n",
#     169        "      <td>0</td>\n",
#     170        "      <td>tcp</td>\n",
#     171        "      <td>http</td>\n",
#     172        "      <td>SF</td>\n",
#     173        "      <td>219</td>\n",
#     174        "      <td>1337</td>\n",
#     175        "      <td>0</td>\n",
#     176        "      <td>0</td>\n",
#     177        "      <td>0</td>\n",
#     178        "      <td>0</td>\n",
#     179        "      <td>...</td>\n",
#     180        "      <td>39</td>\n",
#     181        "      <td>1.0</td>\n",
#     182        "      <td>0.0</td>\n",
#     183        "      <td>0.03</td>\n",
#     184        "      <td>0.0</td>\n",
#     185        "      <td>0.0</td>\n",
#     186        "      <td>0.0</td>\n",
#     187        "      <td>0.0</td>\n",
#     188        "      <td>0.0</td>\n",
#     189        "      <td>normal.</td>\n",
#     190        "    </tr>\n",
#     191        "    <tr>\n",
#     192        "      <th>4</th>\n",
#     193        "      <td>0</td>\n",
#     194        "      <td>tcp</td>\n",
#     195        "      <td>http</td>\n",
#     196        "      <td>SF</td>\n",
#     197        "      <td>217</td>\n",
#     198        "      <td>2032</td>\n",
#     199        "      <td>0</td>\n",
#     200        "      <td>0</td>\n",
#     201        "      <td>0</td>\n",
#     202        "      <td>0</td>\n",
#     203        "      <td>...</td>\n",
#     204        "      <td>49</td>\n",
#     205        "      <td>1.0</td>\n",
#     206        "      <td>0.0</td>\n",
#     207        "      <td>0.02</td>\n",
#     208        "      <td>0.0</td>\n",
#     209        "      <td>0.0</td>\n",
#     210        "      <td>0.0</td>\n",
#     211        "      <td>0.0</td>\n",
#     212        "      <td>0.0</td>\n",
#     213        "      <td>normal.</td>\n",
#     214        "    </tr>\n",
#     215        "  </tbody>\n",
#     216        "</table>\n",
# --> 217        "<p>5 rows × 42 columns</p>\n",
#     218        "</div>"
#     219       ],
#     220       "text/plain": [
#     221        "   duration protocol_type service flag  src_bytes  dst_bytes  land  \\\n",
#     222        "0         0           tcp    http   SF        181       5450     0   \n",
#     223        "1         0           tcp    http   SF        239        486     0   \n",
#     224        "2         0           tcp    http   SF        235       1337     0   \n",
#     225        "3         0           tcp    http   SF        219       1337     0   \n",
#     226        "4         0           tcp    http   SF        217       2032     0   \n",
#     227        "\n",
#     228        "   wrong_fragment  urgent  hot  ...  dst_host_srv_count  \\\n",
#     229        "0               0       0    0  ...                   9   \n",
#     230        "1               0       0    0  ...                  19   \n",
#     231        "2               0       0    0  ...                  29   \n",
#     232        "3               0       0    0  ...                  39   \n",
#     233        "4               0       0    0  ...                  49   \n",
#     234        "\n",
#     235        "   dst_host_same_srv_rate  dst_host_diff_srv_rate  \\\n",
#     236        "0                     1.0                     0.0   \n",
#     237        "1                     1.0                     0.0   \n",
#     238        "2                     1.0                     0.0   \n",
#     239        "3                     1.0                     0.0   \n",
#     240        "4                     1.0                     0.0   \n",
#     241        "\n",
#     242        "   dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \\\n",
#     243        "0                         0.11                          0.0   \n",
#     244        "1                         0.05                          0.0   \n",
#     245        "2                         0.03                          0.0   \n",
#     246        "3                         0.03                          0.0   \n",
#     247        "4                         0.02                          0.0   \n",
#     248        "\n",
#     249        "   dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \\\n",
#     250        "0                   0.0                       0.0                   0.0   \n",
#     251        "1                   0.0                       0.0                   0.0   \n",
#     252        "2                   0.0                       0.0                   0.0   \n",
#     253        "3                   0.0                       0.0                   0.0   \n",
#     254        "4                   0.0                       0.0                   0.0   \n",
#     255        "\n",
#     256        "   dst_host_srv_rerror_rate    label  \n",
#     257        "0                       0.0  normal.  \n",
#     258        "1                       0.0  normal.  \n",
#     259        "2                       0.0  normal.  \n",
#     260        "3                       0.0  normal.  \n",
#     261        "4                       0.0  normal.  \n",
#     262        "\n",
#     263        "[5 rows x 42 columns]"
#     264       ]
#     265      },
#     266      "execution_count": 3,
#     267      "metadata": {},
#     268      "output_type": "execute_result"
#     269     }
#     270    ],
#     271    "source": [
#     272     "# Visualize the data to understand the format    \n",
#     273     "df = pd.read_csv('kddcup.data_10_percent.gz', names = features)\n",
#     274     "df.head()"
#     275    ]
#     276   },
#     277   {
#     278    "cell_type": "code",
#     279    "execution_count": 4,
#     280    "id": "5bd980df",
#     281    "metadata": {
#     282     "scrolled": true
#     283    },
#     284    "outputs": [
#     285     {
#     286      "data": {
#     287       "text/html": [
#     288        "<div>\n",
#     289        "<style scoped>\n",
#     290        "    .dataframe tbody tr th:only-of-type {\n",
#     291        "        vertical-align: middle;\n",
#     292        "    }\n",
#     293        "\n",
#     294        "    .dataframe tbody tr th {\n",
#     295        "        vertical-align: top;\n",
#     296        "    }\n",
#     297        "\n",
#     298        "    .dataframe thead th {\n",
#     299        "        text-align: right;\n",
#     300        "    }\n",
#     301        "</style>\n",
#     302        "<table border=\"1\" class=\"dataframe\">\n",
#     303        "  <thead>\n",
#     304        "    <tr style=\"text-align: right;\">\n",
#     305        "      <th></th>\n",
#     306        "      <th>duration</th>\n",
#     307        "      <th>src_bytes</th>\n",
#     308        "      <th>dst_bytes</th>\n",
#     309        "      <th>land</th>\n",
#     310        "      <th>wrong_fragment</th>\n",
#     311        "      <th>urgent</th>\n",
#     312        "      <th>hot</th>\n",
#     313        "      <th>num_failed_logins</th>\n",
#     314        "      <th>logged_in</th>\n",
#     315        "      <th>num_compromised</th>\n",
#     316        "      <th>...</th>\n",
#     317        "      <th>dst_host_count</th>\n",
#     318        "      <th>dst_host_srv_count</th>\n",
#     319        "      <th>dst_host_same_srv_rate</th>\n",
#     320        "      <th>dst_host_diff_srv_rate</th>\n",
#     321        "      <th>dst_host_same_src_port_rate</th>\n",
#     322        "      <th>dst_host_srv_diff_host_rate</th>\n",
#     323        "      <th>dst_host_serror_rate</th>\n",
#     324        "      <th>dst_host_srv_serror_rate</th>\n",
#     325        "      <th>dst_host_rerror_rate</th>\n",
#     326        "      <th>dst_host_srv_rerror_rate</th>\n",
#     327        "    </tr>\n",
#     328        "  </thead>\n",
#     329        "  <tbody>\n",
#     330        "    <tr>\n",
#     331        "      <th>count</th>\n",
#     332        "      <td>494021.000000</td>\n",
#     333        "      <td>4.940210e+05</td>\n",
#     334        "      <td>4.940210e+05</td>\n",
#     335        "      <td>494021.000000</td>\n",
#     336        "      <td>494021.000000</td>\n",
#     337        "      <td>494021.000000</td>\n",
#     338        "      <td>494021.000000</td>\n",
#     339        "      <td>494021.000000</td>\n",
#     340        "      <td>494021.000000</td>\n",
#     341        "      <td>494021.000000</td>\n",
#     342        "      <td>...</td>\n",
#     343        "      <td>494021.000000</td>\n",
#     344        "      <td>494021.000000</td>\n",
#     345        "      <td>494021.000000</td>\n",
#     346        "      <td>494021.000000</td>\n",
#     347        "      <td>494021.000000</td>\n",
#     348        "      <td>494021.000000</td>\n",
#     349        "      <td>494021.000000</td>\n",
#     350        "      <td>494021.000000</td>\n",
#     351        "      <td>494021.000000</td>\n",
#     352        "      <td>494021.000000</td>\n",
#     353        "    </tr>\n",
#     354        "    <tr>\n",
#     355        "      <th>mean</th>\n",
#     356        "      <td>47.979302</td>\n",
#     357        "      <td>3.025610e+03</td>\n",
#     358        "      <td>8.685324e+02</td>\n",
#     359        "      <td>0.000045</td>\n",
#     360        "      <td>0.006433</td>\n",
#     361        "      <td>0.000014</td>\n",
#     362        "      <td>0.034519</td>\n",
#     363        "      <td>0.000152</td>\n",
#     364        "      <td>0.148247</td>\n",
#     365        "      <td>0.010212</td>\n",
#     366        "      <td>...</td>\n",
#     367        "      <td>232.470778</td>\n",
#     368        "      <td>188.665670</td>\n",
#     369        "      <td>0.753780</td>\n",
#     370        "      <td>0.030906</td>\n",
#     371        "      <td>0.601935</td>\n",
#     372        "      <td>0.006684</td>\n",
#     373        "      <td>0.176754</td>\n",
#     374        "      <td>0.176443</td>\n",
#     375        "      <td>0.058118</td>\n",
#     376        "      <td>0.057412</td>\n",
#     377        "    </tr>\n",
#     378        "    <tr>\n",
#     379        "      <th>std</th>\n",
#     380        "      <td>707.746472</td>\n",
#     381        "      <td>9.882181e+05</td>\n",
#     382        "      <td>3.304000e+04</td>\n",
#     383        "      <td>0.006673</td>\n",
#     384        "      <td>0.134805</td>\n",
#     385        "      <td>0.005510</td>\n",
#     386        "      <td>0.782103</td>\n",
#     387        "      <td>0.015520</td>\n",
#     388        "      <td>0.355345</td>\n",
#     389        "      <td>1.798326</td>\n",
#     390        "      <td>...</td>\n",
#     391        "      <td>64.745380</td>\n",
#     392        "      <td>106.040437</td>\n",
#     393        "      <td>0.410781</td>\n",
#     394        "      <td>0.109259</td>\n",
#     395        "      <td>0.481309</td>\n",
#     396        "      <td>0.042133</td>\n",
#     397        "      <td>0.380593</td>\n",
#     398        "      <td>0.380919</td>\n",
#     399        "      <td>0.230590</td>\n",
#     400        "      <td>0.230140</td>\n",
#     401        "    </tr>\n",
#     402        "    <tr>\n",
#     403        "      <th>min</th>\n",
#     404        "      <td>0.000000</td>\n",
#     405        "      <td>0.000000e+00</td>\n",
#     406        "      <td>0.000000e+00</td>\n",
#     407        "      <td>0.000000</td>\n",
#     408        "      <td>0.000000</td>\n",
#     409        "      <td>0.000000</td>\n",
#     410        "      <td>0.000000</td>\n",
#     411        "      <td>0.000000</td>\n",
#     412        "      <td>0.000000</td>\n",
#     413        "      <td>0.000000</td>\n",
#     414        "      <td>...</td>\n",
#     415        "      <td>0.000000</td>\n",
#     416        "      <td>0.000000</td>\n",
#     417        "      <td>0.000000</td>\n",
#     418        "      <td>0.000000</td>\n",
#     419        "      <td>0.000000</td>\n",
#     420        "      <td>0.000000</td>\n",
#     421        "      <td>0.000000</td>\n",
#     422        "      <td>0.000000</td>\n",
#     423        "      <td>0.000000</td>\n",
#     424        "      <td>0.000000</td>\n",
#     425        "    </tr>\n",
#     426        "    <tr>\n",
#     427        "      <th>25%</th>\n",
#     428        "      <td>0.000000</td>\n",
#     429        "      <td>4.500000e+01</td>\n",
#     430        "      <td>0.000000e+00</td>\n",
#     431        "      <td>0.000000</td>\n",
#     432        "      <td>0.000000</td>\n",
#     433        "      <td>0.000000</td>\n",
#     434        "      <td>0.000000</td>\n",
#     435        "      <td>0.000000</td>\n",
#     436        "      <td>0.000000</td>\n",
#     437        "      <td>0.000000</td>\n",
#     438        "      <td>...</td>\n",
#     439        "      <td>255.000000</td>\n",
#     440        "      <td>46.000000</td>\n",
#     441        "      <td>0.410000</td>\n",
#     442        "      <td>0.000000</td>\n",
#     443        "      <td>0.000000</td>\n",
#     444        "      <td>0.000000</td>\n",
#     445        "      <td>0.000000</td>\n",
#     446        "      <td>0.000000</td>\n",
#     447        "      <td>0.000000</td>\n",
#     448        "      <td>0.000000</td>\n",
#     449        "    </tr>\n",
#     450        "    <tr>\n",
#     451        "      <th>50%</th>\n",
#     452        "      <td>0.000000</td>\n",
#     453        "      <td>5.200000e+02</td>\n",
#     454        "      <td>0.000000e+00</td>\n",
#     455        "      <td>0.000000</td>\n",
#     456        "      <td>0.000000</td>\n",
#     457        "      <td>0.000000</td>\n",
#     458        "      <td>0.000000</td>\n",
#     459        "      <td>0.000000</td>\n",
#     460        "      <td>0.000000</td>\n",
#     461        "      <td>0.000000</td>\n",
#     462        "      <td>...</td>\n",
#     463        "      <td>255.000000</td>\n",
#     464        "      <td>255.000000</td>\n",
#     465        "      <td>1.000000</td>\n",
#     466        "      <td>0.000000</td>\n",
#     467        "      <td>1.000000</td>\n",
#     468        "      <td>0.000000</td>\n",
#     469        "      <td>0.000000</td>\n",
#     470        "      <td>0.000000</td>\n",
#     471        "      <td>0.000000</td>\n",
#     472        "      <td>0.000000</td>\n",
#     473        "    </tr>\n",
#     474        "    <tr>\n",
#     475        "      <th>75%</th>\n",
#     476        "      <td>0.000000</td>\n",
#     477        "      <td>1.032000e+03</td>\n",
#     478        "      <td>0.000000e+00</td>\n",
#     479        "      <td>0.000000</td>\n",
#     480        "      <td>0.000000</td>\n",
#     481        "      <td>0.000000</td>\n",
#     482        "      <td>0.000000</td>\n",
#     483        "      <td>0.000000</td>\n",
#     484        "      <td>0.000000</td>\n",
#     485        "      <td>0.000000</td>\n",
#     486        "      <td>...</td>\n",
#     487        "      <td>255.000000</td>\n",
#     488        "      <td>255.000000</td>\n",
#     489        "      <td>1.000000</td>\n",
#     490        "      <td>0.040000</td>\n",
#     491        "      <td>1.000000</td>\n",
#     492        "      <td>0.000000</td>\n",
#     493        "      <td>0.000000</td>\n",
#     494        "      <td>0.000000</td>\n",
#     495        "      <td>0.000000</td>\n",
#     496        "      <td>0.000000</td>\n",
#     497        "    </tr>\n",
#     498        "    <tr>\n",
#     499        "      <th>max</th>\n",
#     500        "      <td>58329.000000</td>\n",
#     501        "      <td>6.933756e+08</td>\n",
#     502        "      <td>5.155468e+06</td>\n",
#     503        "      <td>1.000000</td>\n",
#     504        "      <td>3.000000</td>\n",
#     505        "      <td>3.000000</td>\n",
#     506        "      <td>30.000000</td>\n",
#     507        "      <td>5.000000</td>\n",
#     508        "      <td>1.000000</td>\n",
#     509        "      <td>884.000000</td>\n",
#     510        "      <td>...</td>\n",
#     511        "      <td>255.000000</td>\n",
#     512        "      <td>255.000000</td>\n",
#     513        "      <td>1.000000</td>\n",
#     514        "      <td>1.000000</td>\n",
#     515        "      <td>1.000000</td>\n",
#     516        "      <td>1.000000</td>\n",
#     517        "      <td>1.000000</td>\n",
#     518        "      <td>1.000000</td>\n",
#     519        "      <td>1.000000</td>\n",
#     520        "      <td>1.000000</td>\n",
#     521        "    </tr>\n",
#     522        "  </tbody>\n",
#     523        "</table>\n",
#     524        "<p>8 rows × 38 columns</p>\n",
#     525        "</div>"
#     526       ],
#     527       "text/plain": [
#     528        "            duration     src_bytes     dst_bytes           land  \\\n",
#     529        "count  494021.000000  4.940210e+05  4.940210e+05  494021.000000   \n",
#     530        "mean       47.979302  3.025610e+03  8.685324e+02       0.000045   \n",
#     531        "std       707.746472  9.882181e+05  3.304000e+04       0.006673   \n",
#     532        "min         0.000000  0.000000e+00  0.000000e+00       0.000000   \n",
#     533        "25%         0.000000  4.500000e+01  0.000000e+00       0.000000   \n",
#     534        "50%         0.000000  5.200000e+02  0.000000e+00       0.000000   \n",
#     535        "75%         0.000000  1.032000e+03  0.000000e+00       0.000000   \n",
#     536        "max     58329.000000  6.933756e+08  5.155468e+06       1.000000   \n",
#     537        "\n",
#     538        "       wrong_fragment         urgent            hot  num_failed_logins  \\\n",
#     539        "count   494021.000000  494021.000000  494021.000000      494021.000000   \n",
#     540        "mean         0.006433       0.000014       0.034519           0.000152   \n",
#     541        "std          0.134805       0.005510       0.782103           0.015520   \n",
#     542        "min          0.000000       0.000000       0.000000           0.000000   \n",
#     543        "25%          0.000000       0.000000       0.000000           0.000000   \n",
#     544        "50%          0.000000       0.000000       0.000000           0.000000   \n",
#     545        "75%          0.000000       0.000000       0.000000           0.000000   \n",
#     546        "max          3.000000       3.000000      30.000000           5.000000   \n",
#     547        "\n",
#     548        "           logged_in  num_compromised  ...  dst_host_count  \\\n",
#     549        "count  494021.000000    494021.000000  ...   494021.000000   \n",
#     550        "mean        0.148247         0.010212  ...      232.470778   \n",
#     551        "std         0.355345         1.798326  ...       64.745380   \n",
#     552        "min         0.000000         0.000000  ...        0.000000   \n",
#     553        "25%         0.000000         0.000000  ...      255.000000   \n",
#     554        "50%         0.000000         0.000000  ...      255.000000   \n",
#     555        "75%         0.000000         0.000000  ...      255.000000   \n",
#     556        "max         1.000000       884.000000  ...      255.000000   \n",
#     557        "\n",
#     558        "       dst_host_srv_count  dst_host_same_srv_rate  dst_host_diff_srv_rate  \\\n",
#     559        "count       494021.000000           494021.000000           494021.000000   \n",
#     560        "mean           188.665670                0.753780                0.030906   \n",
#     561        "std            106.040437                0.410781                0.109259   \n",
#     562        "min              0.000000                0.000000                0.000000   \n",
#     563        "25%             46.000000                0.410000                0.000000   \n",
#     564        "50%            255.000000                1.000000                0.000000   \n",
#     565        "75%            255.000000                1.000000                0.040000   \n",
#     566        "max            255.000000                1.000000                1.000000   \n",
#     567        "\n",
#     568        "       dst_host_same_src_port_rate  dst_host_srv_diff_host_rate  \\\n",
#     569        "count                494021.000000                494021.000000   \n",
#     570        "mean                      0.601935                     0.006684   \n",
#     571        "std                       0.481309                     0.042133   \n",
#     572        "min                       0.000000                     0.000000   \n",
#     573        "25%                       0.000000                     0.000000   \n",
#     574        "50%                       1.000000                     0.000000   \n",
#     575        "75%                       1.000000                     0.000000   \n",
#     576        "max                       1.000000                     1.000000   \n",
#     577        "\n",
#     578        "       dst_host_serror_rate  dst_host_srv_serror_rate  dst_host_rerror_rate  \\\n",
#     579        "count         494021.000000             494021.000000         494021.000000   \n",
#     580        "mean               0.176754                  0.176443              0.058118   \n",
#     581        "std                0.380593                  0.380919              0.230590   \n",
#     582        "min                0.000000                  0.000000              0.000000   \n",
#     583        "25%                0.000000                  0.000000              0.000000   \n",
#     584        "50%                0.000000                  0.000000              0.000000   \n",
#     585        "75%                0.000000                  0.000000              0.000000   \n",
#     586        "max                1.000000                  1.000000              1.000000   \n",
#     587        "\n",
#     588        "       dst_host_srv_rerror_rate  \n",
#     589        "count             494021.000000  \n",
#     590        "mean                   0.057412  \n",
#     591        "std                    0.230140  \n",
#     592        "min                    0.000000  \n",
#     593        "25%                    0.000000  \n",
#     594        "50%                    0.000000  \n",
#     595        "75%                    0.000000  \n",
#     596        "max                    1.000000  \n",
#     597        "\n",
#     598        "[8 rows x 38 columns]"
#     599       ]
#     600      },
#     601      "execution_count": 4,
#     602      "metadata": {},
#     603      "output_type": "execute_result"
#     604     }
#     605    ],
#     606    "source": [
#     607     "df.describe()"
#     608    ]
#     609   },
#     610   {
#     611    "cell_type": "code",
#     612    "execution_count": 5,
#     613    "id": "8038c7e3",
#     614    "metadata": {
#     615     "scrolled": true
#     616    },
#     617    "outputs": [
#     618     {
#     619      "name": "stdout",
#     620      "output_type": "stream",
#     621      "text": [
#     622       "Number of datapoints:  494021\n",
#     623       "Number of features: 42\n",
#     624       "Features are: ['duration', 'protocol_type', 'service', 'flag', 'src_bytes', 'dst_bytes', 'land', 'wrong_fragment', 'urgent', 'hot', 'num_failed_logins', 'logged_in', 'num_compromised', 'root_shell', 'su_attempted', 'num_root', 'num_file_creations', 'num_shells', 'num_access_files', 'num_outbound_cmds', 'is_host_login', 'is_guest_login', 'count', 'srv_count', 'serror_rate', 'srv_serror_rate', 'rerror_rate', 'srv_rerror_rate', 'same_srv_rate', 'diff_srv_rate', 'srv_diff_host_rate', 'dst_host_count', 'dst_host_srv_count', 'dst_host_same_srv_rate', 'dst_host_diff_srv_rate', 'dst_host_same_src_port_rate', 'dst_host_srv_diff_host_rate', 'dst_host_serror_rate', 'dst_host_srv_serror_rate', 'dst_host_rerror_rate', 'dst_host_srv_rerror_rate', 'label']\n"
#     625      ]
#     626     }
#     627    ],
#     628    "source": [
#     629     "print('Number of datapoints: ',df.shape[0])\n",
#     630     "print('Number of features:',df.shape[1])\n",
#     631     "print(\"Features are:\",features)"
#     632    ]
#     633   },
#     634   {
#     635    "cell_type": "code",
#     636    "execution_count": 6,
#     637    "id": "d0058468",
#     638    "metadata": {
#     639     "scrolled": true
#     640    },
#     641    "outputs": [
#     642     {
#     643      "data": {
#     644       "text/plain": [
#     645        "count     494021\n",
#     646        "unique        23\n",
#     647        "top       smurf.\n",
#     648        "freq      280790\n",
#     649        "Name: label, dtype: object"
#     650       ]
#     651      },
#     652      "execution_count": 6,
#     653      "metadata": {},
#     654      "output_type": "execute_result"
#     655     }
#     656    ],
#     657    "source": [
#     658     "# True class labels\n",
#     659     "description = df['label'].describe()\n",
#     660     "description"
#     661    ]
#     662   },
#     663   {
#     664    "cell_type": "code",
#     665    "execution_count": 7,
#     666    "id": "24807af5",
#     667    "metadata": {},
#     668    "outputs": [
#     669     {
#     670      "data": {
#     671       "text/plain": [
#     672        "array(['normal.', 'buffer_overflow.', 'loadmodule.', 'perl.', 'neptune.',\n",
#     673        "       'smurf.', 'guess_passwd.', 'pod.', 'teardrop.', 'portsweep.',\n",
#     674        "       'ipsweep.', 'land.', 'ftp_write.', 'back.', 'imap.', 'satan.',\n",
#     675        "       'phf.', 'nmap.', 'multihop.', 'warezmaster.', 'warezclient.',\n",
#     676        "       'spy.', 'rootkit.'], dtype=object)"
#     677       ]
#     678      },
#     679      "execution_count": 7,
#     680      "metadata": {},
#     681      "output_type": "execute_result"
#     682     }
#     683    ],
#     684    "source": [
#     685     "df['label'].unique()"
#     686    ]
#     687   },
#     688   {
#     689    "cell_type": "markdown",
#     690    "id": "7bc3da75",
#     691    "metadata": {},
#     692    "source": [
#     693     "### Data Preprocessing"
#     694    ]
#     695   },
#     696   {
#     697    "cell_type": "code",
#     698    "execution_count": 8,
#     699    "id": "d1657934",
#     700    "metadata": {},
#     701    "outputs": [
#     702     {
#     703      "name": "stdout",
#     704      "output_type": "stream",
#     705      "text": [
#     706       "Null values in dataset are 0\n"
#     707      ]
#     708     }
#     709    ],
#     710    "source": [
#     711     "print('Null values in dataset are',len(df[df.isnull().any(1)]))"
#     712    ]
#     713   },
#     714   {
#     715    "cell_type": "markdown",
#     716    "id": "8f3109cf",
#     717    "metadata": {},
#     718    "source": [
#     719     "#### Dropping Duplicates"
#     720    ]
#     721   },
#     722   {
#     723    "cell_type": "code",
#     724    "execution_count": 9,
#     725    "id": "9960ef1a",
#     726    "metadata": {},
#     727    "outputs": [
#     728     {
#     729      "data": {
#     730       "text/plain": [
#     731        "(145586, 42)"
#     732       ]
#     733      },
#     734      "execution_count": 9,
#     735      "metadata": {},
#     736      "output_type": "execute_result"
#     737     }
#     738    ],
#     739    "source": [
#     740     "# Dropping duplicates\n",
#     741     "df.drop_duplicates(subset=features, keep='first', inplace = True)\n",
#     742     "df.shape"
#     743    ]
#     744   },
#     745   {
#     746    "cell_type": "markdown",
#     747    "id": "76dd7c0a",
#     748    "metadata": {},
#     749    "source": [
#     750     "#### Removing Redundant Attributes\n",
#     751     "\n"
#     752    ]
#     753   },
#     754   {
#     755    "cell_type": "code",
#     756    "execution_count": 10,
#     757    "id": "0def5886",
#     758    "metadata": {
#     759     "scrolled": true
#     760    },
#     761    "outputs": [
#     762     {
#     763      "name": "stdout",
#     764      "output_type": "stream",
#     765      "text": [
#     766       "Value counts for duration:\n",
#     767       "0        134975\n",
#     768       "1          2441\n",
#     769       "2           853\n",
#     770       "3           604\n",
#     771       "5           407\n",
#     772       "          ...  \n",
#     773       "1877          1\n",
#     774       "6186          1\n",
#     775       "4262          1\n",
#     776       "18185         1\n",
#     777       "120           1\n",
#     778       "Name: duration, Length: 2495, dtype: int64\n",
#     779       "Value counts for protocol_type:\n",
#     780       "tcp     130913\n",
#     781       "udp      12267\n",
#     782       "icmp      2406\n",
#     783       "Name: protocol_type, dtype: int64\n",
#     784       "Value counts for service:\n",
#     785       "http        62054\n",
#     786       "private     49057\n",
#     787       "smtp         9721\n",
#     788       "domain_u     5425\n",
#     789       "other        4769\n",
#     790       "            ...  \n",
#     791       "X11            11\n",
#     792       "tim_i           5\n",
#     793       "pm_dump         1\n",
#     794       "tftp_u          1\n",
#     795       "red_i           1\n",
#     796       "Name: service, Length: 66, dtype: int64\n",
#     797       "Value counts for flag:\n",
#     798       "SF        87459\n",
#     799       "S0        42278\n",
#     800       "REJ       14712\n",
#     801       "RSTO        569\n",
#     802       "RSTR        425\n",
#     803       "S1           57\n",
#     804       "SH           34\n",
#     805       "S2           24\n",
#     806       "RSTOS0       11\n",
#     807       "S3           10\n",
#     808       "OTH           7\n",
#     809       "Name: flag, dtype: int64\n",
#     810       "Value counts for src_bytes:\n",
#     811       "0        57872\n",
#     812       "147       1962\n",
#     813       "105       1467\n",
#     814       "146       1454\n",
#     815       "42         941\n",
#     816       "         ...  \n",
#     817       "6927         1\n",
#     818       "2315         1\n",
#     819       "11898        1\n",
#     820       "12289        1\n",
#     821       "475          1\n",
#     822       "Name: src_bytes, Length: 3300, dtype: int64\n",
#     823       "Value counts for dst_bytes:\n",
#     824       "0        67663\n",
#     825       "105       3199\n",
#     826       "8314       899\n",
#     827       "330        854\n",
#     828       "329        804\n",
#     829       "         ...  \n",
#     830       "4205         1\n",
#     831       "4519         1\n",
#     832       "4268         1\n",
#     833       "7391         1\n",
#     834       "13828        1\n",
#     835       "Name: dst_bytes, Length: 10725, dtype: int64\n",
#     836       "Value counts for land:\n",
#     837       "0    145566\n",
#     838       "1        20\n",
#     839       "Name: land, dtype: int64\n",
#     840       "Value counts for wrong_fragment:\n",
#     841       "0    144465\n",
#     842       "3       910\n",
#     843       "1       211\n",
#     844       "Name: wrong_fragment, dtype: int64\n",
#     845       "Value counts for urgent:\n",
#     846       "0    145582\n",
#     847       "1         2\n",
#     848       "2         1\n",
#     849       "3         1\n",
#     850       "Name: urgent, dtype: int64\n",
#     851       "Value counts for hot:\n",
#     852       "0     143629\n",
#     853       "2        958\n",
#     854       "28       274\n",
#     855       "1        255\n",
#     856       "4        112\n",
#     857       "6        104\n",
#     858       "5         51\n",
#     859       "3         38\n",
#     860       "14        37\n",
#     861       "30        28\n",
#     862       "22        28\n",
#     863       "19        23\n",
#     864       "24        13\n",
#     865       "18        13\n",
#     866       "20        10\n",
#     867       "7          5\n",
#     868       "17         2\n",
#     869       "12         2\n",
#     870       "16         1\n",
#     871       "10         1\n",
#     872       "15         1\n",
#     873       "9          1\n",
#     874       "Name: hot, dtype: int64\n",
#     875       "Value counts for num_failed_logins:\n",
#     876       "0    145523\n",
#     877       "1        57\n",
#     878       "2         3\n",
#     879       "5         1\n",
#     880       "4         1\n",
#     881       "3         1\n",
#     882       "Name: num_failed_logins, dtype: int64\n",
#     883       "Value counts for logged_in:\n",
#     884       "0    74032\n",
#     885       "1    71554\n",
#     886       "Name: logged_in, dtype: int64\n",
#     887       "Value counts for num_compromised:\n",
#     888       "0      144596\n",
#     889       "1         917\n",
#     890       "2          24\n",
#     891       "4          16\n",
#     892       "3          11\n",
#     893       "6           3\n",
#     894       "5           2\n",
#     895       "7           2\n",
#     896       "767         1\n",
#     897       "12          1\n",
#     898       "9           1\n",
#     899       "884         1\n",
#     900       "13          1\n",
#     901       "38          1\n",
#     902       "18          1\n",
#     903       "11          1\n",
#     904       "275         1\n",
#     905       "281         1\n",
#     906       "16          1\n",
#     907       "238         1\n",
#     908       "21          1\n",
#     909       "22          1\n",
#     910       "102         1\n",
#     911       "Name: num_compromised, dtype: int64\n",
#     912       "Value counts for root_shell:\n",
#     913       "0    145531\n",
#     914       "1        55\n",
#     915       "Name: root_shell, dtype: int64\n",
#     916       "Value counts for su_attempted:\n",
#     917       "0    145574\n",
#     918       "1         6\n",
#     919       "2         6\n",
#     920       "Name: su_attempted, dtype: int64\n",
#     921       "Value counts for num_root:\n",
#     922       "0      145001\n",
#     923       "1         233\n",
#     924       "9         167\n",
#     925       "6         126\n",
#     926       "2          22\n",
#     927       "5          12\n",
#     928       "4          10\n",
#     929       "3           3\n",
#     930       "7           1\n",
#     931       "993         1\n",
#     932       "54          1\n",
#     933       "306         1\n",
#     934       "14          1\n",
#     935       "39          1\n",
#     936       "278         1\n",
#     937       "268         1\n",
#     938       "12          1\n",
#     939       "857         1\n",
#     940       "16          1\n",
#     941       "119         1\n",
#     942       "Name: num_root, dtype: int64\n",
#     943       "Value counts for num_file_creations:\n",
#     944       "0     145321\n",
#     945       "1        207\n",
#     946       "2         36\n",
#     947       "4          7\n",
#     948       "16         2\n",
#     949       "5          1\n",
#     950       "22         1\n",
#     951       "25         1\n",
#     952       "12         1\n",
#     953       "8          1\n",
#     954       "7          1\n",
#     955       "21         1\n",
#     956       "14         1\n",
#     957       "10         1\n",
#     958       "28         1\n",
#     959       "9          1\n",
#     960       "15         1\n",
#     961       "20         1\n",
#     962       "Name: num_file_creations, dtype: int64\n",
#     963       "Value counts for num_shells:\n",
#     964       "0    145535\n",
#     965       "1        48\n",
#     966       "2         3\n",
#     967       "Name: num_shells, dtype: int64\n",
#     968       "Value counts for num_access_files:\n",
#     969       "0    145133\n",
#     970       "1       423\n",
#     971       "2        25\n",
#     972       "3         2\n",
#     973       "4         1\n",
#     974       "6         1\n",
#     975       "8         1\n",
#     976       "Name: num_access_files, dtype: int64\n",
#     977       "Value counts for num_outbound_cmds:\n",
#     978       "0    145586\n",
#     979       "Name: num_outbound_cmds, dtype: int64\n",
#     980       "Value counts for is_host_login:\n",
#     981       "0    145586\n",
#     982       "Name: is_host_login, dtype: int64\n",
#     983       "Value counts for is_guest_login:\n",
#     984       "0    144901\n",
#     985       "1       685\n",
#     986       "Name: is_guest_login, dtype: int64\n",
#     987       "Value counts for count:\n",
#     988       "1      30439\n",
#     989       "2       9409\n",
#     990       "3       5371\n",
#     991       "4       4984\n",
#     992       "5       4178\n",
#     993       "       ...  \n",
#     994       "395        1\n",
#     995       "385        1\n",
#     996       "375        1\n",
#     997       "345        1\n",
#     998       "407        1\n",
#     999       "Name: count, Length: 490, dtype: int64\n",
#    1000       "Value counts for srv_count:\n",
#    1001       "1      25054\n",
#    1002       "2      14475\n",
#    1003       "3       8254\n",
#    1004       "4       7109\n",
#    1005       "5       6246\n",
#    1006       "       ...  \n",
#    1007       "386        1\n",
#    1008       "379        1\n",
#    1009       "373        1\n",
#    1010       "358        1\n",
#    1011       "407        1\n",
#    1012       "Name: srv_count, Length: 470, dtype: int64\n",
#    1013       "Value counts for serror_rate:\n",
#    1014       "0.00    101813\n",
#    1015       "1.00     41746\n",
#    1016       "0.99       308\n",
#    1017       "0.06       106\n",
#    1018       "0.07       100\n",
#    1019       "         ...  \n",
#    1020       "0.87         1\n",
#    1021       "0.80         1\n",
#    1022       "0.90         1\n",
#    1023       "0.34         1\n",
#    1024       "0.89         1\n",
#    1025       "Name: serror_rate, Length: 92, dtype: int64\n",
#    1026       "Value counts for srv_serror_rate:\n",
#    1027       "0.00    102055\n",
#    1028       "1.00     42250\n",
#    1029       "0.03       139\n",
#    1030       "0.04       120\n",
#    1031       "0.05       109\n",
#    1032       "0.06        98\n",
#    1033       "0.02        84\n",
#    1034       "0.50        77\n",
#    1035       "0.08        73\n",
#    1036       "0.07        68\n",
#    1037       "0.25        56\n",
#    1038       "0.33        55\n",
#    1039       "0.17        51\n",
#    1040       "0.09        48\n",
#    1041       "0.10        46\n",
#    1042       "0.20        44\n",
#    1043       "0.12        43\n",
#    1044       "0.11        43\n",
#    1045       "0.14        34\n",
#    1046       "0.01        10\n",
#    1047       "0.67         9\n",
#    1048       "0.18         6\n",
#    1049       "0.92         6\n",
#    1050       "0.95         5\n",
#    1051       "0.94         5\n",
#    1052       "0.88         4\n",
#    1053       "0.19         4\n",
#    1054       "0.58         4\n",
#    1055       "0.75         4\n",
#    1056       "0.83         3\n",
#    1057       "0.76         3\n",
#    1058       "0.15         3\n",
#    1059       "0.91         3\n",
#    1060       "0.40         3\n",
#    1061       "0.85         2\n",
#    1062       "0.27         2\n",
#    1063       "0.22         2\n",
#    1064       "0.93         2\n",
#    1065       "0.16         1\n",
#    1066       "0.38         1\n",
#    1067       "0.36         1\n",
#    1068       "0.35         1\n",
#    1069       "0.45         1\n",
#    1070       "0.21         1\n",
#    1071       "0.44         1\n",
#    1072       "0.23         1\n",
#    1073       "0.51         1\n",
#    1074       "0.86         1\n",
#    1075       "0.90         1\n",
#    1076       "0.80         1\n",
#    1077       "0.37         1\n",
#    1078       "Name: srv_serror_rate, dtype: int64\n",
#    1079       "Value counts for rerror_rate:\n",
#    1080       "0.00    129222\n",
#    1081       "1.00     14987\n",
#    1082       "0.25        75\n",
#    1083       "0.50        73\n",
#    1084       "0.01        62\n",
#    1085       "         ...  \n",
#    1086       "0.66         1\n",
#    1087       "0.31         1\n",
#    1088       "0.32         1\n",
#    1089       "0.34         1\n",
#    1090       "0.24         1\n",
#    1091       "Name: rerror_rate, Length: 77, dtype: int64\n",
#    1092       "Value counts for srv_rerror_rate:\n",
#    1093       "0.00    128822\n",
#    1094       "1.00     15467\n",
#    1095       "0.50       168\n",
#    1096       "0.33       158\n",
#    1097       "0.25       131\n",
#    1098       "0.20        88\n",
#    1099       "0.17        81\n",
#    1100       "0.14        68\n",
#    1101       "0.04        63\n",
#    1102       "0.03        61\n",
#    1103       "0.12        57\n",
#    1104       "0.06        54\n",
#    1105       "0.02        54\n",
#    1106       "0.05        41\n",
#    1107       "0.07        36\n",
#    1108       "0.67        28\n",
#    1109       "0.08        28\n",
#    1110       "0.11        26\n",
#    1111       "0.40        24\n",
#    1112       "0.09        24\n",
#    1113       "0.29        20\n",
#    1114       "0.10        16\n",
#    1115       "0.75        11\n",
#    1116       "0.60        10\n",
#    1117       "0.01         6\n",
#    1118       "0.71         4\n",
#    1119       "0.22         4\n",
#    1120       "0.83         3\n",
#    1121       "0.86         3\n",
#    1122       "0.18         2\n",
#    1123       "0.96         2\n",
#    1124       "0.79         2\n",
#    1125       "0.43         2\n",
#    1126       "0.92         2\n",
#    1127       "0.81         2\n",
#    1128       "0.88         2\n",
#    1129       "0.73         2\n",
#    1130       "0.69         1\n",
#    1131       "0.94         1\n",
#    1132       "0.62         1\n",
#    1133       "0.80         1\n",
#    1134       "0.85         1\n",
#    1135       "0.93         1\n",
#    1136       "0.82         1\n",
#    1137       "0.27         1\n",
#    1138       "0.37         1\n",
#    1139       "0.21         1\n",
#    1140       "0.38         1\n",
#    1141       "0.87         1\n",
#    1142       "0.95         1\n",
#    1143       "0.13         1\n",
#    1144       "Name: srv_rerror_rate, dtype: int64\n",
#    1145       "Value counts for same_srv_rate:\n",
#    1146       "1.00    90096\n",
#    1147       "0.06     5072\n",
#    1148       "0.05     4858\n",
#    1149       "0.04     4778\n",
#    1150       "0.03     4583\n",
#    1151       "        ...  \n",
# ...
#    1761        "494020          0            0          0        0        0        0        0   \n",
#    1762        "\n",
#    1763        "        flag_SF  flag_SH  \n",
#    1764        "0             1        0  \n",
#    1765        "1             1        0  \n",
#    1766        "2             1        0  \n",
#    1767        "3             1        0  \n",
#    1768        "4             1        0  \n",
#    1769        "...         ...      ...  \n",
#    1770        "494016        1        0  \n",
#    1771        "494017        1        0  \n",
#    1772        "494018        1        0  \n",
#    1773        "494019        1        0  \n",
#    1774        "494020        1        0  \n",
#    1775        "\n",
#    1776        "[145586 rows x 117 columns]"
#    1777       ]
#    1778      },
#    1779      "execution_count": 13,
#    1780      "metadata": {},
#    1781      "output_type": "execute_result"
#    1782     }
#    1783    ],
#    1784    "source": [
#    1785     "df_encoded"
#    1786    ]
#    1787   },
#    1788   {
#    1789    "cell_type": "markdown",
#    1790    "id": "818bbc62",
#    1791    "metadata": {},
#    1792    "source": [
#    1793     "#### Standardization of continuous features"
#    1794    ]
#    1795   },
#    1796   {
#    1797    "cell_type": "code",
#    1798    "execution_count": 14,
#    1799    "id": "d3c51362",
#    1800    "metadata": {},
#    1801    "outputs": [],
#    1802    "source": [
#    1803     "numeric = ['duration',\n",
#    1804     " 'src_bytes',\n",
#    1805     " 'dst_bytes',\n",
#    1806     " 'land',\n",
#    1807     " 'wrong_fragment',\n",
#    1808     " 'urgent',\n",
#    1809     " 'hot',\n",
#    1810     " 'num_failed_logins',\n",
#    1811     " 'logged_in',\n",
#    1812     " 'num_compromised',\n",
#    1813     " 'root_shell',\n",
#    1814     " 'su_attempted',\n",
#    1815     " 'num_root',\n",
#    1816     " 'num_file_creations',\n",
#    1817     " 'num_shells',\n",
#    1818     " 'num_access_files',\n",
#    1819     " 'is_guest_login',\n",
#    1820     " 'count',\n",
#    1821     " 'srv_count',\n",
#    1822     " 'serror_rate',\n",
#    1823     " 'srv_serror_rate',\n",
#    1824     " 'rerror_rate',\n",
#    1825     " 'srv_rerror_rate',\n",
#    1826     " 'same_srv_rate',\n",
#    1827     " 'diff_srv_rate',\n",
#    1828     " 'srv_diff_host_rate',\n",
#    1829     " 'dst_host_count',\n",
#    1830     " 'dst_host_srv_count',\n",
#    1831     " 'dst_host_same_srv_rate',\n",
#    1832     " 'dst_host_diff_srv_rate',\n",
#    1833     " 'dst_host_same_src_port_rate',\n",
#    1834     " 'dst_host_srv_diff_host_rate',\n",
#    1835     " 'dst_host_serror_rate',\n",
#    1836     " 'dst_host_srv_serror_rate',\n",
#    1837     " 'dst_host_rerror_rate',\n",
#    1838     " 'dst_host_srv_rerror_rate']"
#    1839    ]
#    1840   },
#    1841   {
#    1842    "cell_type": "code",
#    1843    "execution_count": 15,
#    1844    "id": "979115a2",
#    1845    "metadata": {},
#    1846    "outputs": [],
#    1847    "source": [
#    1848     "# instantiate a StandardScaler object\n",
#    1849     "scaler = StandardScaler()\n",
#    1850     "\n",
#    1851     "# fit and transform the continuous features\n",
#    1852     "df_encoded[numeric] = scaler.fit_transform(df_encoded[numeric])"
#    1853    ]
#    1854   },
#    1855   {
#    1856    "cell_type": "code",
#    1857    "execution_count": 16,
#    1858    "id": "0464d1be",
#    1859    "metadata": {
#    1860     "scrolled": false
#    1861    },
#    1862    "outputs": [
#    1863     {
#    1864      "data": {
#    1865       "text/plain": [
#    1866        "array(['normal.', 'buffer_overflow.', 'loadmodule.', 'perl.', 'neptune.',\n",
#    1867        "       'smurf.', 'guess_passwd.', 'pod.', 'teardrop.', 'portsweep.',\n",
#    1868        "       'ipsweep.', 'land.', 'ftp_write.', 'back.', 'imap.', 'satan.',\n",
#    1869        "       'phf.', 'nmap.', 'multihop.', 'warezmaster.', 'warezclient.',\n",
#    1870        "       'spy.', 'rootkit.'], dtype=object)"
#    1871       ]
#    1872      },
#    1873      "execution_count": 16,
#    1874      "metadata": {},
#    1875      "output_type": "execute_result"
#    1876     }
#    1877    ],
#    1878    "source": [
#    1879     "df_encoded['label'].unique()"
#    1880    ]
#    1881   },
#    1882   {
#    1883    "cell_type": "code",
#    1884    "execution_count": 17,
#    1885    "id": "116de225",
#    1886    "metadata": {},
#    1887    "outputs": [],
#    1888    "source": [
#    1889     "data_labels = pd.DataFrame(df_encoded)\n",
#    1890     "\n",
#    1891     "# Instantiate the LabelEncoder object\n",
#    1892     "le = LabelEncoder()\n",
#    1893     "\n",
#    1894     "# Fit the LabelEncoder object on the string values to obtain the encoded labels\n",
#    1895     "data_labels['label'] = le.fit_transform(data_labels['label'])\n"
#    1896    ]
#    1897   },
#    1898   {
#    1899    "cell_type": "code",
#    1900    "execution_count": 18,
#    1901    "id": "dba0b87b",
#    1902    "metadata": {},
#    1903    "outputs": [
#    1904     {
#    1905      "data": {
#    1906       "text/plain": [
#    1907        "normal.             87832\n",
#    1908        "neptune.            51820\n",
#    1909        "back.                 968\n",
#    1910        "teardrop.             918\n",
#    1911        "satan.                906\n",
#    1912        "warezclient.          893\n",
#    1913        "ipsweep.              651\n",
#    1914        "smurf.                641\n",
#    1915        "portsweep.            416\n",
#    1916        "pod.                  206\n",
#    1917        "nmap.                 158\n",
#    1918        "guess_passwd.          53\n",
#    1919        "buffer_overflow.       30\n",
#    1920        "warezmaster.           20\n",
#    1921        "land.                  19\n",
#    1922        "imap.                  12\n",
#    1923        "rootkit.               10\n",
#    1924        "loadmodule.             9\n",
#    1925        "ftp_write.              8\n",
#    1926        "multihop.               7\n",
#    1927        "phf.                    4\n",
#    1928        "perl.                   3\n",
#    1929        "spy.                    2\n",
#    1930        "Name: label, dtype: int64"
#    1931       ]
#    1932      },
#    1933      "execution_count": 18,
#    1934      "metadata": {},
#    1935      "output_type": "execute_result"
#    1936     }
#    1937    ],
#    1938    "source": [
#    1939     "df_encoded['label'].value_counts()"
#    1940    ]
#    1941   },
#    1942   {
#    1943    "cell_type": "code",
#    1944    "execution_count": 19,
#    1945    "id": "0bf628d9",
#    1946    "metadata": {},
#    1947    "outputs": [
#    1948     {
#    1949      "data": {
#    1950       "text/plain": [
#    1951        "11    87832\n",
#    1952        "9     51820\n",
#    1953        "0       968\n",
#    1954        "20      918\n",
#    1955        "17      906\n",
#    1956        "21      893\n",
#    1957        "5       651\n",
#    1958        "18      641\n",
#    1959        "15      416\n",
#    1960        "14      206\n",
#    1961        "10      158\n",
#    1962        "3        53\n",
#    1963        "1        30\n",
#    1964        "22       20\n",
#    1965        "6        19\n",
#    1966        "4        12\n",
#    1967        "16       10\n",
#    1968        "7         9\n",
#    1969        "2         8\n",
#    1970        "8         7\n",
#    1971        "13        4\n",
#    1972        "12        3\n",
#    1973        "19        2\n",
#    1974        "Name: label, dtype: int64"
#    1975       ]
#    1976      },
#    1977      "execution_count": 19,
#    1978      "metadata": {},
#    1979      "output_type": "execute_result"
#    1980     }
#    1981    ],
#    1982    "source": [
#    1983     "data_labels['label'].value_counts()"
#    1984    ]
#    1985   },
#    1986   {
#    1987    "cell_type": "code",
#    1988    "execution_count": 20,
#    1989    "id": "79277cb3",
#    1990    "metadata": {
#    1991     "scrolled": true
#    1992    },
#    1993    "outputs": [
#    1994     {
#    1995      "data": {
#    1996       "text/plain": [
#    1997        "36"
#    1998       ]
#    1999      },
#    2000      "execution_count": 20,
#    2001      "metadata": {},
#    2002      "output_type": "execute_result"
#    2003     }
#    2004    ],
#    2005    "source": [
#    2006     "df_encoded.columns.get_loc('label')"
#    2007    ]
#    2008   },
#    2009   {
#    2010    "cell_type": "code",
#    2011    "execution_count": 21,
#    2012    "id": "c5a7bf75",
#    2013    "metadata": {
#    2014     "scrolled": true
#    2015    },
#    2016    "outputs": [
#    2017     {
#    2018      "data": {
#    2019       "text/plain": [
#    2020        "0         11\n",
#    2021        "1         11\n",
#    2022        "2         11\n",
#    2023        "3         11\n",
#    2024        "4         11\n",
#    2025        "          ..\n",
#    2026        "494016    11\n",
#    2027        "494017    11\n",
#    2028        "494018    11\n",
#    2029        "494019    11\n",
#    2030        "494020    11\n",
#    2031        "Name: label, Length: 145586, dtype: int32"
#    2032       ]
#    2033      },
#    2034      "execution_count": 21,
#    2035      "metadata": {},
#    2036      "output_type": "execute_result"
#    2037     }
#    2038    ],
#    2039    "source": [
#    2040     "data_labels.iloc[:, 36]"
#    2041    ]
#    2042   },
#    2043   {
#    2044    "cell_type": "code",
#    2045    "execution_count": 22,
#    2046    "id": "84231ea3",
#    2047    "metadata": {},
#    2048    "outputs": [
#    2049     {
#    2050      "data": {
#    2051       "text/plain": [
#    2052        "18"
#    2053       ]
#    2054      },
#    2055      "execution_count": 22,
#    2056      "metadata": {},
#    2057      "output_type": "execute_result"
#    2058     }
#    2059    ],
#    2060    "source": [
#    2061     "data_labels['label'][397013]"
#    2062    ]
#    2063   },
#    2064   {
#    2065    "cell_type": "code",
#    2066    "execution_count": 23,
#    2067    "id": "f967bb76",
#    2068    "metadata": {},
#    2069    "outputs": [
#    2070     {
#    2071      "data": {
#    2072       "text/plain": [
#    2073        "'smurf.'"
#    2074       ]
#    2075      },
#    2076      "execution_count": 23,
#    2077      "metadata": {},
#    2078      "output_type": "execute_result"
#    2079     }
#    2080    ],
#    2081    "source": [
#    2082     "df_encoded['label'][397013]"
#    2083    ]
#    2084   },
#    2085   {
#    2086    "cell_type": "code",
#    2087    "execution_count": 24,
#    2088    "id": "7f3ee33f",
#    2089    "metadata": {},
#    2090    "outputs": [],
#    2091    "source": [
#    2092     "df_encoded.drop('label',inplace=True,axis=1)"
#    2093    ]
#    2094   },
#    2095   {
#    2096    "cell_type": "code",
#    2097    "execution_count": 25,
#    2098    "id": "7d72e098",
#    2099    "metadata": {},
#    2100    "outputs": [],
#    2101    "source": [
#    2102     "def preprocess_data_10():\n",
#    2103     "    # Load data from file\n",
#    2104     "    df = pd.read_csv('kddcup.data_10_percent.gz', names = features)\n",
#    2105     "    \n",
#    2106     "    # Perform preprocessing steps\n",
#    2107     "    # Dropping duplicate values\n",
#    2108     "    df.drop_duplicates(subset=features, keep='first', inplace = True)\n",
#    2109     "\n",
#    2110     "    # Removing Redundant Attributes Attributes\n",
#    2111     "    df.drop('num_outbound_cmds', axis=1, inplace=True)\n",
#    2112     "    df.drop('is_host_login', axis=1, inplace=True)\n",
#    2113     "    \n",
#    2114     "    # One hot encoding for categorical features\n",
#    2115     "    df_encoded = pd.get_dummies(df, columns=['protocol_type','service','flag'])\n",
#    2116     "    \n",
#    2117     "    # Standardization of numerical features\n",
#    2118     "    scaler = StandardScaler()\n",
#    2119     "    df_encoded[numeric] = scaler.fit_transform(df_encoded[numeric])\n",
#    2120     "\n",
#    2121     "    # Convert categorical labels (23) classes to numbers\n",
#    2122     "    le = LabelEncoder()\n",
#    2123     "    data_labels = pd.DataFrame(df_encoded)\n",
#    2124     "    data_labels['label'] = le.fit_transform(data_labels['label'])\n",
#    2125     "\n",
#    2126     "    idx = df_encoded.columns.get_loc('label')\n",
#    2127     "    # Split data into features and labels\n",
#    2128     "    y = data_labels.iloc[:, idx]\n",
#    2129     "    df_encoded.drop('label',inplace=True,axis=1)\n",
#    2130     "    X = df_encoded\n",
#    2131     "\n",
#    2132     "    # Return preprocessed data and labels\n",
#    2133     "    return X, y"
#    2134    ]
#    2135   },
#    2136   {
#    2137    "cell_type": "code",
#    2138    "execution_count": 26,
#    2139    "id": "1f2c56d2",
#    2140    "metadata": {},
#    2141    "outputs": [],
#    2142    "source": [
#    2143     "def preprocess_data():\n",
#    2144     "    # Load data from file\n",
#    2145     "    df = pd.read_csv('kddcup.data.corrected', names = features)\n",
#    2146     "    \n",
#    2147     "    # Perform preprocessing steps\n",
#    2148     "    # Dropping duplicate values\n",
#    2149     "    df.drop_duplicates(subset=features, keep='first', inplace = True)\n",
#    2150     "\n",
#    2151     "    # Removing Redundant Attributes Attributes\n",
#    2152     "    df.drop('num_outbound_cmds', axis=1, inplace=True)\n",
#    2153     "    df.drop('is_host_login', axis=1, inplace=True)\n",
#    2154     "    \n",
#    2155     "    # One hot encoding for categorical features\n",
#    2156     "    df_encoded = pd.get_dummies(df, columns=['protocol_type','service','flag'])\n",
#    2157     "    \n",
#    2158     "    # Standardization of numerical features\n",
#    2159     "    scaler = StandardScaler()\n",
#    2160     "    df_encoded[numeric] = scaler.fit_transform(df_encoded[numeric])\n",
#    2161     "\n",
#    2162     "    # Convert categorical labels (23) classes to numbers\n",
#    2163     "    le = LabelEncoder()\n",
#    2164     "    data_labels = pd.DataFrame(df_encoded)\n",
#    2165     "    data_labels['label'] = le.fit_transform(data_labels['label'])\n",
#    2166     "\n",
#    2167     "    idx = df_encoded.columns.get_loc('label')\n",
#    2168     "    # Split data into features and labels\n",
#    2169     "    y = data_labels.iloc[:, idx]\n",
#    2170     "    df_encoded.drop('label',inplace=True,axis=1)\n",
#    2171     "    X = df_encoded\n",
#    2172     "\n",
#    2173     "    # Return preprocessed data and labels\n",
#    2174     "    return X, y"
#    2175    ]
#    2176   },
#    2177   {
#    2178    "cell_type": "code",
#    2179    "execution_count": 27,
#    2180    "id": "02534575",
#    2181    "metadata": {},
#    2182    "outputs": [],
#    2183    "source": [
#    2184     "def category(x):\n",
#    2185     "    dict_categories = {\n",
#    2186     "    0: 'back.',\n",
#    2187     "    1: 'buffer_overflow.',\n",
#    2188     "    2: 'ftp_write.',\n",
#    2189     "    3: 'guess_passwd.',\n",
#    2190     "    4: 'imap.',\n",
#    2191     "    5: 'ipsweep.',\n",
#    2192     "    6: 'land.',\n",
#    2193     "    7: 'loadmodule.',\n",
#    2194     "    8: 'multihop.',\n",
#    2195     "    9: 'neptune.',\n",
#    2196     "    10: 'nmap.',\n",
#    2197     "    11: 'normal.',\n",
#    2198     "    12: 'perl.',\n",
#    2199     "    13: 'phf.',\n",
#    2200     "    14: 'pod.',\n",
#    2201     "    15: 'portsweep.',\n",
#    2202     "    16: 'rootkit.',\n",
#    2203     "    17: 'satan.',\n",
#    2204     "    18: 'smurf.',\n",
#    2205     "    19: 'spy.',\n",
#    2206     "    20: 'teardrop.',\n",
#    2207     "    21: 'warezclient.',\n",
#    2208     "    22: 'warezmaster.'\n",
#    2209     "}\n",
#    2210     "    return dict_categories[x]"
#    2211    ]
#    2212   }
#    2213  ],
#    2214  "metadata": {
#    2215   "kernelspec": {
#    2216    "display_name": "Python 3 (ipykernel)",
#    2217    "language": "python",
#    2218    "name": "python3"
#    2219   },
#    2220   "language_info": {
#    2221    "codemirror_mode": {
#    2222     "name": "ipython",
#    2223     "version": 3
#    2224    },
#    2225    "file_extension": ".py",
#    2226    "mimetype": "text/x-python",
#    2227    "name": "python",
#    2228    "nbconvert_exporter": "python",
#    2229    "pygments_lexer": "ipython3",
#    2230    "version": "3.9.12"
#    2231   }
#    2232  },
#    2233  "nbformat": 4,
#    2234  "nbformat_minor": 5
#    2235 }
#
# NameError: name 'dict_categories' is not defined

# %%
sim_matrix=rbf_kernel(X_train)

# %%
system,labels=spectral_clustering(sim_matrix,23)

# %%
contingency_matrix = get_contingency(23,labels,y_train)
evaluation(X_train,contingency_matrix)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 contingency_matrix = get_contingency(23,labels,y_train)
#       2 evaluation(X_train,contingency_matrix)
#
# NameError: name 'get_contingency' is not defined

# %% [markdown]
# ## Comparison between K-means and Spectral Clustering

# %%
labels = kMeans_implemented(23,np.array(X_train))
contingency_matrix = get_contingency(23,labels,np.array(y_train))
evaluation(X_train,contingency_matrix)

# %% [markdown]
# ## GMM Testing

# %%
labels = gmm(23,np.array(X_train))
contingency_matrix = get_contingency(23,labels,np.array(y_train))
evaluation(X_train,contingency_matrix)

# %% [markdown]
# # Evaluation

# %%
# map labels resulting in k-means to true labels in able to do predictions
def map_and_change(y_train, labels):
    mapping = {}
    labels = np.array(list(labels))
    for i in np.unique(labels):
        binary = [int(x) for x in labels == i]
        mapping[i] = np.bincount([value for value, flag in zip(y_train, binary) if flag == 1]).argmax()

    # Map the cluster labels to the true class labels
    mapped_labels = np.array([mapping[label] for label in labels])

    # Print the mapped labels
    print(mapping)
    return mapping, mapped_labels

# %%
def map_and_change_test(mapping, labels):
    mapped_labels = np.array([mapping[label] for label in labels])
    return mapped_labels

# %%
new_labels = map_and_change(y_train,labels)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 new_labels = map_and_change(y_train,labels)
#
# NameError: name 'y_train' is not defined

# %%
def get_contingency(k,labels,true):
    labels = list(labels)
    true = list(true)
    num_classes = k
    num_elements = len(labels)
    contingency_matrix = np.zeros((23,k))
    for i in range(num_elements):
        contingency_matrix[true[i],labels[i]] += 1
    return contingency_matrix

# %%
def evaluation(data, contingency_matrix):
    n_total = data.shape[0]
    gt_classes=contingency_matrix.shape[0]
    predicted_classes=contingency_matrix.shape[1]
#     TP, TN, FP, FN = 0, 0, 0, 0
#     # True Positive 
#     for i in range(gt_classes):
#         for j in range(predicted_classes):
#             if contingency_matrix[i][j] != 1 and contingency_matrix[i][j] != 0:
#                 TP += math.comb(int(contingency_matrix[i][j]),2)

#     # True Negative 
#     for i in range(gt_classes):
#         for j in range(predicted_classes):
#             if i != j:
#                 for k in range(predicted_classes):
#                     temp = contingency_matrix[k,i]*(np.sum(contingency_matrix[:,j]) - contingency_matrix[k,j])
#                     TN += temp
#     TN = TN/2

#     # False Positive 
#     for i in range(gt_classes):
#         for j in range(predicted_classes):
#             temp = contingency_matrix[j,i]*(np.sum(contingency_matrix[:,i])-contingency_matrix[j,i])/2
#             FP += temp

#     # False Negative 
#     for i in range(gt_classes):
#         for j in range(predicted_classes):
#             if i != j:
#                 for k in range(predicted_classes):
#                     temp = contingency_matrix[k,i]*(contingency_matrix[k,j])
#                     FN += temp
#     FN /= 2

#     # Jaccard Index
#     jacc = TP / (TP + FN + FP)

#     # Rand Index
#     rand = (TP + TN)/ (TP + FN + FP + TN)
#     print('---------Confusion Matrix----------------------')
#     print(f"Rand Index: {rand}")
    
#     print(f"Jaccard Index: {jacc}")
#     print(f'TP= {TP},TN= {TN},FN= {FN},FP= {FP}')
    
    ht_c = 0
    for i in range(predicted_classes):
        cluster_elem = np.sum(contingency_matrix[:,i])
        for j in range(gt_classes):  
            temp = contingency_matrix[j][i]/cluster_elem
            if temp != 0:
                ht_c += temp*math.log(temp,2)*(cluster_elem/n_total)
    ht_c = -1*ht_c
    print('---------Conditional Entropy--------------------')
    print(f"Conditional Entropy: {ht_c}")
    
    print('----------------Purity---------------------------')
    purity=0
    purities=[]
    recalls=[]
    for i in range(predicted_classes):
        cluster_sum=np.sum(contingency_matrix[:,i])
        class_max=np.max(contingency_matrix[:,i])
        a=contingency_matrix[:,i]
        max_index=a.argmax()
        purities.append(class_max/cluster_sum)
        recalls.append(class_max/np.sum(contingency_matrix[max_index,:]))
        purity+=(class_max/cluster_sum) * (cluster_sum/n_total)
    #purity = np.sum(np.max(contingency_matrix, axis =0))/np.sum(contingency_matrix)
    print(f"Purity: {purity}")
    
    print('--------------F-measure---------------------------')
    # a row for each cluster, and columns are precision, recall and F-measure respectively
    
    f_measure=0
    for i in range(predicted_classes):
        f_measure+=(2*purities[i]*recalls[i])/(purities[i]+recalls[i])
    f_measure=f_measure/predicted_classes
    print(f"F: {f_measure}")
    
    print('--------------Max matching------------------------')
    row_ind, col_ind = linear_sum_assignment(contingency_matrix, maximize=True)
    contingency_reordered = contingency_matrix[row_ind][:, col_ind]
    #print(contingency_reordered)
    max_match = np.sum(np.diag(contingency_reordered))/np.sum(contingency_matrix)
    print(f"Max Matching: {max_match}")

# %% [markdown]
# # Testing K-means using Test Data set and Mapping Clusters to Classes

# %%
X_train, X_test, y_train, y_test = train_test_split(data_spectral, labels_spectral, test_size=0.995, train_size=0.005,stratify=labels_spectral,random_state=42)

# %%
kmeans = KMeans(n_clusters=23, random_state=42)

# %%
kmeans.fit(X_train)

# %%
train_labels = kmeans.labels_

# %%
mapping, train_labels = map_and_change(y_train, train_labels)

# %%
test_labels = kmeans.predict(X_test)

# %%
test_labels = map_and_change_test(mapping,test_labels)

# %%
accuracy = accuracy_score(test_labels, y_test)

# %%
print(f"Accuracy: {accuracy}")
